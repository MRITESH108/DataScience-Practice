# %% [markdown]
# <a href="https://colab.research.google.com/github/MRITESH108/DataScience-Practice/blob/main/Practice4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
                                                                       # SeaBorn library

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips= sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# create a scatter plot

sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Scatter plot of total bill vs tip")
plt.show()

# %%
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Line plot of size vs total bill")
plt.show()

# %%
# categorical plot
# bar plot

sns.barplot(x='day', y='total_bill', data=tips)
plt.title("Bar plot of day vs total bill")
plt.show()

# %%
# box plot
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title("Box plot of day vs total bill")
plt.show()

# %%
# violin plot

sns.violinplot(x='day', y='total_bill', data=tips)
plt.title("Violin plot of day vs total bill")
plt.show()

# %%
# histogram

sns.histplot(x='total_bill', data=tips)
plt.title("Histogram of total bill")
plt.show()

# %%
sns.histplot(tips['total_bill'],bins=10, kde=True)
plt.title("Histogram of total bill")
plt.show()

# %%
sns.histplot(tips['total_bill'],bins=100, kde=False)
plt.title("Histogram of total bill")
plt.show()

# %%
# KDE Plot

sns.kdeplot(tips['total_bill'])
plt.title("KDE Plot of total bill")
plt.show()

# %%
# KDE Plot

sns.kdeplot(tips['total_bill'],shade=True)
plt.title("KDE Plot of total bill")
plt.show()
# Out:
# /tmp/ipython-input-23-1737382704.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'],shade=True)

# %%
# pairplot

sns.pairplot(tips)
plt.show()

# %%
# heatmap

corr= tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')

# plt.show()
# Out:
# <Axes: >

# %%
import pandas as pd
sales= pd.read_csv('/content/sample_data/california_housing_train.csv')
sales.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# plot total rooms

plt.figure(figsize=(10,6))
sns.barplot(x='total_rooms', y='longitude', data=sales)
plt.title("Bar plot of total rooms")
plt.show()
