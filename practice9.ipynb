# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
import pandas as pd

df = pd.DataFrame({
    'size': ['small', 'medium', 'large', 'medium', 'small', 'large'],
    # 'color': ['blue', 'green', 'red', 'green', 'blue', 'red'],
})

# %%
import pandas as pd

df = pd.DataFrame({
    'size': ['small', 'medium', 'large', 'medium', 'small', 'large'],
    # 'color': ['blue', 'green', 'red', 'green', 'blue', 'red'],
})
df
# Out:
#      size
# 0   small
# 1  medium
# 2   large
# 3  medium
# 4   small
# 5   large

# %%
# create an instance of ordinal ecoder and then fit trajsform
encoder = OrdinalEncoder(categories=[['small', 'medium', 'large']])
encoder.fit_transform(df[['size']])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [2.]])

# %%
encoder.transform([['small']])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# array([[0.]])

# %%
df = pd.DataFrame({
    'city': ['New York', 'Berlin', 'Berlin', 'London', 'London', 'Berlin'],
    'price': [100, 200, 150, 300, 250, 400],
})
df
# Out:
#        city  price
# 0  New York    100
# 1    Berlin    200
# 2    Berlin    150
# 3    London    300
# 4    London    250
# 5    Berlin    400

# %%
mean_price=df.groupby('city')['price'].mean().to_dict()

# %%
mean_price
# Out:
# {'Berlin': 250.0, 'London': 275.0, 'New York': 100.0}

# %%
df['city_encoded']=df['city'].map(mean_price)

# %%
df[['price','city_encoded']]
# Out:
#    price  city_encoded
# 0    100         100.0
# 1    200         250.0
# 2    150         250.0
# 3    300         275.0
# 4    250         275.0
# 5    400         250.0

# %%
import seaborn as sns
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
